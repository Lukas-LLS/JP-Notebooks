# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Data/cereal.csv')
df
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 0        Total Corn Flakes   G    C       110        2    1     200    0.0
# 1             Lucky Charms   G    C       110        2    1     180    0.0
# 2                  Triples   G    C       110        2    1     250    0.0
# 3                     Trix   G    C       110        1    1     140    0.0
# 4               Wheat Chex   R    C       100        3    1     230    3.0
# 5       Great Grains Pecan   P    C       120        3    3      75    3.0
# 6            Rice Krispies   K    C       110        2    0     290    0.0
# 7       Quaker Oat Squares   Q    C       100        4    1     135    2.0
# 8    Cinnamon Toast Crunch   G    C       120        1    3     210    0.0
# 9       Cracklin' Oat Bran   K    C       110        3    3     140    4.0
# 10               Corn Chex   R    C       110        2    0     280    0.0
# ...

# %%
# Create a correlation matrix with seaborn
sns.heatmap(df.drop(columns = ['name', 'mfr', 'type']).corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df['rating'], bins=6, color='black')
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
sns.regplot(data=df, x='potass', y='fiber', color='black')
# Out:
# <Axes: xlabel='potass', ylabel='fiber'>

# %%
df['mfr'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>
